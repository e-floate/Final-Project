# %%
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.svm import NuSVC
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn import preprocessing

# %%
df_1 = pd.read_csv('data_Post-processing\\df_full_combo_clean.csv')
df_2 = pd.read_csv('data_Post-processing\\df_genuine_middle.csv')
#df_combo = pd.concat([df_1,df_2])
#df_combo.shape
df_1.head()
# Out:
#    Unnamed: 0                    URL  Length  digits  digit_ratio  Hyperlinks  \
# 0           0             poom.co.kr      10       0          0.0        25.0
# 1           1      victoriarnilan.no      17       0          0.0         8.0
# 2           2           paqtomog.com      12       0          0.0        23.0
# 3           3  publications-agora.fr      21       0          0.0        23.0
# 4           4         funkemedien.de      14       0          0.0        25.0
#
#    Sus_Words  Phish  Url_Dots  Sus_Url
# 0        0.0  False         2        0
# 1        0.0  False         1        0
# 2        0.0  False         1        0
# 3        0.0  False         1        0
# 4        0.0  False         1        0

# %%
#df_1.drop(['Unnamed: 0','digits','digit_ratio','Sus_Words'],axis=1,inplace=True)
df_1.head()
# Out:
#                      URL  Length  Hyperlinks  Phish  Url_Dots  Sus_Url
# 0             poom.co.kr      10        25.0  False         2        0
# 1      victoriarnilan.no      17         8.0  False         1        0
# 2           paqtomog.com      12        23.0  False         1        0
# 3  publications-agora.fr      21        23.0  False         1        0
# 4         funkemedien.de      14        25.0  False         1        0

# %%
df_2.drop('Unnamed: 0',axis=1,inplace=True)
df_2.head()
# Out:
#                                                  URL  Length  Hyperlinks  \
# 0             https://www.turkishdelightkebab.co.uk/      38         0.0
# 1  https://twitter.com/search?q=%22South%20Park%2...      79         6.0
# 2   https://twitter.com/i/events/1610420776393445379      48         6.0
# 3                        https://twitter.com/denooh_      27         6.0
# 4                 https://www.reddit.com/r/CasualUK/      34        25.0
#
#    Url_Dots  Sus_Url
# 0         3        0
# 1         1        0
# 2         1        0
# 3         1        0
# 4         2        0

# %%
import re
def url_dots(row):
    digits = re.findall('\.',row['URL'])
    return len(digits)
df_2['Url_Dots'] = df_2.apply(lambda row: url_dots(row),axis=1)
df_2.head()
# Out:
#                                                  URL  Length  Hyperlinks  \
# 0             https://www.turkishdelightkebab.co.uk/      38         0.0
# 1  https://twitter.com/search?q=%22South%20Park%2...      79         6.0
# 2   https://twitter.com/i/events/1610420776393445379      48         6.0
# 3                        https://twitter.com/denooh_      27         6.0
# 4                 https://www.reddit.com/r/CasualUK/      34        25.0
#
#    Url_Dots
# 0         3
# 1         1
# 2         1
# 3         1
# 4         2

# %%
df_1.head()
# Out:
#                      URL  Length  Hyperlinks  Phish  Url_Dots
# 0             poom.co.kr      10        25.0  False         2
# 1      victoriarnilan.no      17         8.0  False         1
# 2           paqtomog.com      12        23.0  False         1
# 3  publications-agora.fr      21        23.0  False         1
# 4         funkemedien.de      14        25.0  False         1

# %%
df_1_clean = df_1.dropna()
df_1_clean.shape
# Out:
# (7354, 6)

# %%
df_2_clean = df_2.dropna()
df_2_clean.shape
# Out:
# (3305, 5)

# %%
df_2.shape
# Out:
# (3305, 3)

# %%
genuine_bool = []
for i in range(0,len(df_2['URL'])):
    genuine_bool.append(False)

# %%
len(genuine_bool)
# Out:
# 3305

# %%
df_2_clean['Phish'] = genuine_bool
df_2_clean.tail()
# Out:
#                                                     URL  Length  Hyperlinks  \
# 3300  https://www.ebay.co.uk/sme/beauty-scent/offers...      74        17.0
# 3301  https://www.ebay.co.uk/sme/beauty-scent/Save-w...      62        17.0
# 3302  https://www.ebay.co.uk/sme/beauty-scent/Save-w...      70        17.0
# 3303  https://www.ebay.co.uk/sme/beauty-scent/Save-w...     153        17.0
# 3304  https://www.ebay.co.uk/sme/beauty-scent/Save-w...     153        17.0
#
#       Url_Dots  Sus_Url  Phish
# 3300         5        0  False
# 3301         3        0  False
# 3302         4        0  False
# 3303         5        0  False
# 3304         5        0  False

# %%
df_combo = pd.concat([df_1_clean,df_2_clean])
df_combo.head()
# Out:
#                      URL  Length  Hyperlinks  Phish  Url_Dots  Sus_Url
# 0             poom.co.kr      10        25.0  False         2        0
# 1      victoriarnilan.no      17         8.0  False         1        0
# 2           paqtomog.com      12        23.0  False         1        0
# 3  publications-agora.fr      21        23.0  False         1        0
# 4         funkemedien.de      14        25.0  False         1        0

# %%
#df_combo.dropna(inplace=True)
df_combo.shape
# Out:
# (10659, 6)

# %%
df_combo.to_csv('Data_Post-processing\\df_combo_middle.csv')

# %%
df_combo_clean = df_combo.dropna()
df_combo_clean.shape
# Out:
# (10659, 5)

# %%
df_combo.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)
df_combo.tail()
# Out:
#                 Date_Time  Score  \
# 1863  2023-02-05 21:57:54    1.9
# 1864  2023-02-05 21:57:52    1.9
# 1865  2023-02-05 21:57:43    1.9
# 1866  2023-02-05 19:52:04    3.3
# 1867  2023-02-05 19:51:48    3.1
#
#                                                     URL  \
# 1863              http://beinmatchonline.com/acc/cc.php
# 1864                     http://beinmatchonline.com/acc
# 1865                  http://attemailnotice.weebly.com/
# 1866  https://cbcenterprodutionsprom.com/casasbahia/...
# 1867                              http://opensea.com.bz
#
#                              IP  Length  digits  digit_ratio  Hyperlinks  \
# 1863               92.205.4.171      37       0          0.0         1.0
# 1864               92.205.4.171      30       0          0.0         1.0
# 1865              199.34.228.53      33       0          0.0         1.0
# 1866  2606:4700:3034::6815:1186      54       0          0.0         2.0
# ...

# %%
df_combo.to_csv('df_sus_words_combined.csv')

# %%
df_combo.head()
df_combo.shape
# Out:
# (3273, 9)

# %%
df_combo.drop_duplicates('URL').shape
# Out:
# (2435, 9)

# %%
df_combo.drop_duplicates('URL').to_csv('df_sus_words_combined.csv')

# %%
df_3 = pd.read_csv('df_sus_words_clean_1_2.csv')

# %%
df_combo_2 = pd.concat([df_combo,df_3])

# %%
df_combo_2.shape
# Out:
# (3825, 10)

# %%
df_combo_2_clean = df_combo_2.drop_duplicates('URL')
df_combo_2_clean.to_csv('df_sus_words_combined.csv')

# %%
df_combo_2_clean.head()
# Out:
#              Date_Time  Score  \
# 0  2023-02-09 07:54:34    3.5
# 1  2023-02-09 07:54:31    2.2
# 2  2023-02-09 07:54:29    2.2
# 3  2023-02-09 07:54:26    4.1
# 4  2023-02-09 07:54:14    5.6
#
#                                                  URL               IP  Length  \
# 0            https://647cyu.z8.web.core.windows.net/      20.60.72.33      39
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...   159.138.16.166     228
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...  110.238.127.235     229
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...    159.138.80.33     227
# 4  http://portogran.com.br/loges/wp-set/main/view...   187.17.111.105      96
#
#    digits  digit_ratio  Hyperlinks  Sus_Words  Unnamed: 0
# 0       4     0.102564         0.0        1.0         NaN
# 1      42     0.184211         0.0        0.0         NaN
# 2      42     0.183406         0.0        0.0         NaN
# 3      41     0.180617         0.0        0.0         NaN
# ...

# %%
df_combo_2_clean.drop('Unnamed: 0',axis=1,inplace=True)
df_combo_2_clean.head()
# Out:
# C:\Users\peter\AppData\Local\Temp\ipykernel_20180\3280945043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combo_2_clean.drop('Unnamed: 0',axis=1,inplace=True)
#              Date_Time  Score  \
# 0  2023-02-09 07:54:34    3.5
# 1  2023-02-09 07:54:31    2.2
# 2  2023-02-09 07:54:29    2.2
# 3  2023-02-09 07:54:26    4.1
# 4  2023-02-09 07:54:14    5.6
#
#                                                  URL               IP  Length  \
# 0            https://647cyu.z8.web.core.windows.net/      20.60.72.33      39
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...   159.138.16.166     228
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...  110.238.127.235     229
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...    159.138.80.33     227
# ...

# %%
df_combo.to_csv('df_sus_words_combined.csv')

# %%
def concat_and_clean(df1,df2):
    df3 = pd.concat([df1,df2])
    df3.drop_duplicates('URL',inplace=True)
    return df3

# %%
df_combo = pd.read_csv('df_sus_words_combined.csv')
df_combo.describe()
# Out:
#         Unnamed: 0        Score       Length       digits  digit_ratio  \
# count  2987.000000  2987.000000  2987.000000  2987.000000  2987.000000
# mean    561.423837     4.196619    59.484433     7.790760     0.084488
# std     374.948708     1.656041   123.585448    52.690118     0.109833
# min       0.000000     1.000000    14.000000     0.000000     0.000000
# 25%     249.000000     2.800000    32.000000     0.000000     0.000000
# 50%     498.000000     4.300000    43.000000     2.000000     0.038462
# 75%     844.500000     5.600000    66.000000     7.000000     0.131579
# max    1540.000000     8.700000  4247.000000  2011.000000     0.545455
#
#         Hyperlinks    Sus_Words
# count  2987.000000  2987.000000
# mean      4.550720     0.181118
# std       8.183165     1.268535
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       3.000000     0.000000
# max      25.000000    29.000000

# %%
df_combo_2 = pd.read_csv('df_sus_words_clean_2_2.csv')
df_combo_3 = concat_and_clean(df_combo,df_combo_2)
df_combo_3.shape
# Out:
# (4044, 10)

# %%
df_combo_3.head()
# Out:
#    Unnamed: 0            Date_Time  Score  \
# 0           0  2023-02-09 07:54:34    3.5
# 1           1  2023-02-09 07:54:31    2.2
# 2           2  2023-02-09 07:54:29    2.2
# 3           3  2023-02-09 07:54:26    4.1
# 4           4  2023-02-09 07:54:14    5.6
#
#                                                  URL               IP  Length  \
# 0            https://647cyu.z8.web.core.windows.net/      20.60.72.33      39
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...   159.138.16.166     228
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...  110.238.127.235     229
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...    159.138.80.33     227
# 4  http://portogran.com.br/loges/wp-set/main/view...   187.17.111.105      96
#
#    digits  digit_ratio  Hyperlinks  Sus_Words
# 0       4     0.102564         0.0        1.0
# 1      42     0.184211         0.0        0.0
# 2      42     0.183406         0.0        0.0
# 3      41     0.180617         0.0        0.0
# ...

# %%
#df_combo_3.drop('Unnamed: 0',axis=1,inplace=True)
df_combo_3.head()
# Out:
#              Date_Time  Score  \
# 0  2023-02-09 07:54:34    3.5
# 1  2023-02-09 07:54:31    2.2
# 2  2023-02-09 07:54:29    2.2
# 3  2023-02-09 07:54:26    4.1
# 4  2023-02-09 07:54:14    5.6
#
#                                                  URL               IP  Length  \
# 0            https://647cyu.z8.web.core.windows.net/      20.60.72.33      39
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...   159.138.16.166     228
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...  110.238.127.235     229
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...    159.138.80.33     227
# 4  http://portogran.com.br/loges/wp-set/main/view...   187.17.111.105      96
#
#    digits  digit_ratio  Hyperlinks  Sus_Words
# 0       4     0.102564         0.0        1.0
# 1      42     0.184211         0.0        0.0
# 2      42     0.183406         0.0        0.0
# 3      41     0.180617         0.0        0.0
# 4       0     0.000000         1.0        0.0

# %%
df_combo.to_csv('df_sus_words_combined.csv')

# %%
df_combo_3.describe()
# Out:
#              Score       Length       digits  digit_ratio   Hyperlinks  \
# count  4044.000000  4044.000000  4044.000000  4044.000000  4044.000000
# mean      4.181899    58.081602     7.771019     0.090207     4.309594
# std       1.604987   108.989048    46.839731     0.113269     7.942104
# min       1.000000    14.000000     0.000000     0.000000     0.000000
# 25%       2.800000    32.000000     0.000000     0.000000     0.000000
# 50%       4.300000    43.000000     2.000000     0.043478     0.000000
# 75%       5.500000    67.000000     7.000000     0.147059     3.000000
# max       8.700000  4247.000000  2011.000000     0.790514    25.000000
#
#          Sus_Words
# count  4044.000000
# mean      0.160732
# std       1.116016
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      29.000000

# %%
import re

# %%
def sus_word_url(row):
    arr = re.findall(r'(security|login|signin|bank|account|update|include|webs|online)',row['URL'])
    return len(arr)

# %%
df_combo_3['Sus_Url'] = df_combo_3.apply(lambda row: sus_word_url(row),axis=1)
df_combo_3.head()
# Out:
#              Date_Time  Score  \
# 0  2023-02-09 07:54:34    3.5
# 1  2023-02-09 07:54:31    2.2
# 2  2023-02-09 07:54:29    2.2
# 3  2023-02-09 07:54:26    4.1
# 4  2023-02-09 07:54:14    5.6
#
#                                                  URL               IP  Length  \
# 0            https://647cyu.z8.web.core.windows.net/      20.60.72.33      39
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...   159.138.16.166     228
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...  110.238.127.235     229
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...    159.138.80.33     227
# 4  http://portogran.com.br/loges/wp-set/main/view...   187.17.111.105      96
#
#    digits  digit_ratio  Hyperlinks  Sus_Words  Sus_Url
# 0       4     0.102564         0.0        1.0        0
# 1      42     0.184211         0.0        0.0        0
# 2      42     0.183406         0.0        0.0        0
# 3      41     0.180617         0.0        0.0        0
# ...

# %%
df_combo_3.describe()
# Out:
#              Score       Length       digits  digit_ratio   Hyperlinks  \
# count  4044.000000  4044.000000  4044.000000  4044.000000  4044.000000
# mean      4.181899    58.081602     7.771019     0.090207     4.309594
# std       1.604987   108.989048    46.839731     0.113269     7.942104
# min       1.000000    14.000000     0.000000     0.000000     0.000000
# 25%       2.800000    32.000000     0.000000     0.000000     0.000000
# 50%       4.300000    43.000000     2.000000     0.043478     0.000000
# 75%       5.500000    67.000000     7.000000     0.147059     3.000000
# max       8.700000  4247.000000  2011.000000     0.790514    25.000000
#
#          Sus_Words      Sus_Url
# count  4044.000000  4044.000000
# mean      0.160732     0.136993
# std       1.116016     0.446523
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max      29.000000     5.000000

# %%
def dots_url(row):
    arr = re.findall(r'\.',row['URL'])
    return len(arr)

# %%
df_combo_3['Url_Dots'] = df_combo_3.apply(lambda row: dots_url(row),axis=1)
df_combo_3.head()
# Out:
#              Date_Time  Score  \
# 0  2023-02-09 07:54:34    3.5
# 1  2023-02-09 07:54:31    2.2
# 2  2023-02-09 07:54:29    2.2
# 3  2023-02-09 07:54:26    4.1
# 4  2023-02-09 07:54:14    5.6
#
#                                                  URL               IP  Length  \
# 0            https://647cyu.z8.web.core.windows.net/      20.60.72.33      39
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...   159.138.16.166     228
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...  110.238.127.235     229
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...    159.138.80.33     227
# 4  http://portogran.com.br/loges/wp-set/main/view...   187.17.111.105      96
#
#    digits  digit_ratio  Hyperlinks  Sus_Words  Sus_Url  Url_Dots
# 0       4     0.102564         0.0        1.0        0         5
# 1      42     0.184211         0.0        0.0        0         5
# 2      42     0.183406         0.0        0.0        0         5
# ...

# %%
df_combo = pd.read_csv('df_sus_words_combined.csv')

# %%
phish_bool = []
for i in range(0,len(df_combo['Sus_Words'])):
    phish_bool.append(True)

# %%
df_combo['Phish'] = phish_bool
df_combo.head()
# Out:
#    Unnamed: 0            Date_Time  Score  \
# 0           0  2023-02-09 07:54:34    3.5
# 1           1  2023-02-09 07:54:31    2.2
# 2           2  2023-02-09 07:54:29    2.2
# 3           3  2023-02-09 07:54:26    4.1
# 4           4  2023-02-09 07:54:14    5.6
#
#                                                  URL               IP  Length  \
# 0            https://647cyu.z8.web.core.windows.net/      20.60.72.33      39
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...   159.138.16.166     228
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...  110.238.127.235     229
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...    159.138.80.33     227
# 4  http://portogran.com.br/loges/wp-set/main/view...   187.17.111.105      96
#
#    digits  digit_ratio  Hyperlinks  Sus_Words  Sus_Url  Url_Dots  Phish
# 0       4     0.102564         0.0        1.0        0         5   True
# 1      42     0.184211         0.0        0.0        0         5   True
# ...

# %%
df_combo.drop('Unnamed: 0',axis=1,inplace=True)
df_combo.head()
# Out:
#              Date_Time  Score  \
# 0  2023-02-09 07:54:34    3.5
# 1  2023-02-09 07:54:31    2.2
# 2  2023-02-09 07:54:29    2.2
# 3  2023-02-09 07:54:26    4.1
# 4  2023-02-09 07:54:14    5.6
#
#                                                  URL               IP  Length  \
# 0            https://647cyu.z8.web.core.windows.net/      20.60.72.33      39
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...   159.138.16.166     228
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...  110.238.127.235     229
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...    159.138.80.33     227
# 4  http://portogran.com.br/loges/wp-set/main/view...   187.17.111.105      96
#
#    digits  digit_ratio  Hyperlinks  Sus_Words  Sus_Url  Url_Dots  Phish
# 0       4     0.102564         0.0        1.0        0         5   True
# 1      42     0.184211         0.0        0.0        0         5   True
# 2      42     0.183406         0.0        0.0        0         5   True
# ...

# %%
df_phish = pd.read_csv('df_genuine_sus_words_clean.csv')

# %%
df_phish.head()
# Out:
#    Unnamed: 0                    URL  Length  digits  digit_ratio  Hyperlinks  \
# 0           0             poom.co.kr      10       0          0.0        25.0
# 1           1      victoriarnilan.no      17       0          0.0         8.0
# 2           2           paqtomog.com      12       0          0.0        23.0
# 3           3  publications-agora.fr      21       0          0.0        23.0
# 4           4         funkemedien.de      14       0          0.0        25.0
#
#    Sus_words  Phish
# 0        0.0  False
# 1        0.0  False
# 2        0.0  False
# 3        0.0  False
# 4        0.0  False

# %%
#df_phish.drop(['Unnamed: 0'],axis=1,inplace=True)
df_phish.head()
# Out:
#                      URL  Length  digits  digit_ratio  Hyperlinks  Sus_words  \
# 0             poom.co.kr      10       0          0.0        25.0        0.0
# 1      victoriarnilan.no      17       0          0.0         8.0        0.0
# 2           paqtomog.com      12       0          0.0        23.0        0.0
# 3  publications-agora.fr      21       0          0.0        23.0        0.0
# 4         funkemedien.de      14       0          0.0        25.0        0.0
#
#    Phish
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
df_phish.rename({'Sus_words':'Sus_Words'},axis=1,inplace=True)
df_phish.head()
# Out:
#                      URL  Length  digits  digit_ratio  Hyperlinks  Sus_Words  \
# 0             poom.co.kr      10       0          0.0        25.0        0.0
# 1      victoriarnilan.no      17       0          0.0         8.0        0.0
# 2           paqtomog.com      12       0          0.0        23.0        0.0
# 3  publications-agora.fr      21       0          0.0        23.0        0.0
# 4         funkemedien.de      14       0          0.0        25.0        0.0
#
#    Phish  Url_Dots  Sus_Url
# 0  False         2        0
# 1  False         1        0
# 2  False         1        0
# 3  False         1        0
# 4  False         1        0

# %%
df_combo.head()
# Out:
#              Date_Time  Score  \
# 0  2023-02-09 07:54:34    3.5
# 1  2023-02-09 07:54:31    2.2
# 2  2023-02-09 07:54:29    2.2
# 3  2023-02-09 07:54:26    4.1
# 4  2023-02-09 07:54:14    5.6
#
#                                                  URL               IP  Length  \
# 0            https://647cyu.z8.web.core.windows.net/      20.60.72.33      39
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...   159.138.16.166     228
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...  110.238.127.235     229
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...    159.138.80.33     227
# 4  http://portogran.com.br/loges/wp-set/main/view...   187.17.111.105      96
#
#    digits  digit_ratio  Hyperlinks  Sus_Words  Sus_Url  Url_Dots  Phish
# 0       4     0.102564         0.0        1.0        0         5   True
# 1      42     0.184211         0.0        0.0        0         5   True
# 2      42     0.183406         0.0        0.0        0         5   True
# ...

# %%
df_combo.drop(['Date_Time','Score','IP'],axis=1,inplace=True)
df_combo.head()
# Out:
#                                                  URL  Length  digits  \
# 0            https://647cyu.z8.web.core.windows.net/      39       4
# 1  https://30-02-9v-h38g5f-83gfd028egfd-2gfe0-g8w...     228      42
# 2  https://22-02-0-fj39h5rg-38rgf-83gef-08cgw-eg0...     229      42
# 3  https://22-02-0-3rg9hf-3r9fv-wrgvc-wd9jc-ge3r-...     227      41
# 4  http://portogran.com.br/loges/wp-set/main/view...      96       0
#
#    digit_ratio  Hyperlinks  Sus_Words  Sus_Url  Url_Dots  Phish
# 0     0.102564         0.0        1.0        0         5   True
# 1     0.184211         0.0        0.0        0         5   True
# 2     0.183406         0.0        0.0        0         5   True
# 3     0.180617         0.0        0.0        0         5   True
# 4     0.000000         1.0        0.0        2         3   True

# %%
df_phish['Url_Dots'] = df_phish.apply(lambda row: dots_url(row),axis=1)
df_phish.head()
# Out:
#                      URL  Length  digits  digit_ratio  Hyperlinks  Sus_words  \
# 0             poom.co.kr      10       0          0.0        25.0        0.0
# 1      victoriarnilan.no      17       0          0.0         8.0        0.0
# 2           paqtomog.com      12       0          0.0        23.0        0.0
# 3  publications-agora.fr      21       0          0.0        23.0        0.0
# 4         funkemedien.de      14       0          0.0        25.0        0.0
#
#    Phish  Url_Dots
# 0  False         2
# 1  False         1
# 2  False         1
# 3  False         1
# 4  False         1

# %%
df_phish['Sus_Url'] = df_phish.apply(lambda row: sus_word_url(row),axis=1)
df_phish.head()
# Out:
#                      URL  Length  digits  digit_ratio  Hyperlinks  Sus_words  \
# 0             poom.co.kr      10       0          0.0        25.0        0.0
# 1      victoriarnilan.no      17       0          0.0         8.0        0.0
# 2           paqtomog.com      12       0          0.0        23.0        0.0
# 3  publications-agora.fr      21       0          0.0        23.0        0.0
# 4         funkemedien.de      14       0          0.0        25.0        0.0
#
#    Phish  Url_Dots  Sus_Url
# 0  False         2        0
# 1  False         1        0
# 2  False         1        0
# 3  False         1        0
# 4  False         1        0

# %%
df_full_combo = concat_and_clean(df_phish,df_combo)

# %%
df_full_combo.head()
# Out:
#                      URL  Length  digits  digit_ratio  Hyperlinks  Sus_Words  \
# 0             poom.co.kr      10       0          0.0        25.0        0.0
# 1      victoriarnilan.no      17       0          0.0         8.0        0.0
# 2           paqtomog.com      12       0          0.0        23.0        0.0
# 3  publications-agora.fr      21       0          0.0        23.0        0.0
# 4         funkemedien.de      14       0          0.0        25.0        0.0
#
#    Phish  Url_Dots  Sus_Url
# 0  False         2        0
# 1  False         1        0
# 2  False         1        0
# 3  False         1        0
# 4  False         1        0

# %%
df_full_combo.shape
# Out:
# (7354, 9)

# %%
df_full_combo.to_csv('df_full_combo_clean.csv')
